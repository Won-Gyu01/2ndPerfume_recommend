# %%
### read me !! ###

## Development environment

# python - 3.8
# 
#
#

# %%
# 라이브러리 설치
# ultralytics - CV를 포함한 딥러닝작업 관련 라이츠러리 패키지(yolo포함)
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import ultralytics # gpu연결 확인 라이브러리
ultralytics.checks() #gpu연결 확인
# Out:
# Ultralytics YOLOv8.2.2  Python-3.8.18 torch-2.2.2+cu118 CUDA:0 (NVIDIA GeForce RTX 4080, 16376MiB)
# Setup complete  (24 CPUs, 63.9 GB RAM, 233.5/1862.3 GB disk)

# %%
#파일 경로 설정(너 컴퓨터 프로젝트 파일이다,,)
dir = 'C:\Users\user\바탕 화면\spm\data'
# Out:
#   Cell In[2], line 2
#     dir = 'C:\Users\user\바탕 화면\spm\data'
#           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# glob 라이브러리 선언
from glob import glob
# 현재 디렉토리에서 모든 이미지 파일을 찾아 리스트로 반환
train_img_list = glob('C:/Users/user/바탕 화면/spm/data/dataset/train/images/*.jpg') # 훈련용 데이터 이미지
test_img_list = glob('C:/Users/user/바탕 화면/spm/data/dataset/test/images/*.jpg') # 테스트용 데이터 이미지
valid_img_list = glob('C:/Users/user/바탕 화면/spm/data/dataset/valid/images/*.jpg') # 검증용 데이터 (파일 갯수가 맞는지 정확하게 설지 되어있는지)이미지

print(len(train_img_list), len(test_img_list), len(valid_img_list))
# Out:
# 1254 60 119

# %%
# glob 라이브러리 선언
from glob import glob
# 현재 디렉토리에서 모든 텍스트 파일을 찾아 리스트로 반환
train_labels_list = glob('C:/Users/user/바탕 화면/spm/data/dataset/train/labels/*.txt') # ""라벨링 정보
test_labels_list = glob('C:/Users/user/바탕 화면/spm/data/dataset/test/labels/*.txt') # ""라벨링 정보
valid_labels_list = glob('C:/Users/user/바탕 화면/spm/data/dataset/valid/labels/*.txt')

print(len(train_labels_list), len(test_labels_list), len(valid_labels_list))
# Out:
# 1254 60 119

# %%
# !yolo train model=yolov8n.pt data='C:/spm/data/dataset/data.yaml' epochs=100 imgsz=640
# epochs == 반복학습 횟수, imgsz = 이미지 픽셀 nXn, yolo train model=훈련모델경로, data=데이터 yalm파일 경로
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.8.18 torch-2.2.2+cu118 CUDA:0 (NVIDIA GeForce RTX 4080, 16376MiB)
# ...

# %%
import time
t = time.time()
t
# Out:
# 1711894801.297291

# %%
import cv2
from ultralytics import YOLO
import time

angry, fear, happy, neutral, sad, nan = 0, 0, 0, 0, 0, 0

def count_mood(x):
    global angry
    global fear
    global happy
    global neutral
    global sad
    global nan
    if(x==1):
        angry=angry+1
        return angry
    elif(x==2):
        fear=fear+1
        return fear
    elif(x==3):
        happy=happy+1
        return happy
    elif(x==4):
        neutral=neutral+1
        return neutral
    elif(x==5):
        sad=sad+1
        return sad
    else:
        nan=nan+1
        return nan

def print_results(res):
    print("======result======")
    print("nan :",res[0])
    print("angry :",res[1])
    print("fear :",res[2])
    print("happy :",res[3])
    print("neutral :",res[4])
    print("sad :",res[5])
    print("======result======")

def print_output(x):
    out = ['nan','anger', 'fear', 'happy', 'neutral', 'sad']
    if(x==0):
        print(out[0])
    elif(x==1):
        print(out[1])
    elif(x==2):
        print(out[2])
    elif(x==3):
        print(out[3])
    elif(x==4):
        print(out[4])
    elif(x==5):
        print(out[5])
    else:
        print('error')
    


# Load the YOLOv8 model
model = YOLO('/Users/seungbeen/Desktop/wmcr/cam/runs/detect/train7/weights/best.pt')

# Open the video file
cap = cv2.VideoCapture(1)

if cap.isOpened():
    start = time.time()


# Loop through the video frames
while cap.isOpened():
    now = time.time()
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)
        if results[0].boxes:
             clss= results[0].boxes.cls.cpu().detach().numpy().tolist()[0]
             clss = int(clss+1)
        else:
             clss=int(0)

        

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)
        print(clss)
        count_mood(clss)
        if now-start >= 10:
            break

        # Break the loop if 'q' is pressed
       #if cv2.waitKey(1) & 0xFF == ord("q"):
        #    break
    else:
        # Break the loop if the end of the video is reached
        break

#print result

res = [nan,angry, fear, happy, neutral, sad]
output = res.index(max(res))
# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
print_results(res)
print("======output======")
print("index :",output)
print_output(output)
print("======output======")
# Out:
# 2024-04-06 17:39:02.362 python[50232:5866155] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# 0: 384x640 1 happy, 328.1ms
# Speed: 3.2ms preprocess, 328.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 3
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# 0: 384x640 1 happy, 256.9ms
# Speed: 1.6ms preprocess, 256.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 3
#
# 0: 384x640 1 happy, 240.5ms
# Speed: 1.5ms preprocess, 240.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 3
#
# 0: 384x640 1 happy, 240.2ms
# Speed: 1.3ms preprocess, 240.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 3
#
# 0: 384x640 1 happy, 240.3ms
# Speed: 1.4ms preprocess, 240.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 3
#
# ...

# %%
import time
t = time.time()
end = t + 10
print(t,'\n',end)
# Out:
# 1712392682.270161
#  1712392692.270161
